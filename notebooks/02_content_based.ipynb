# %% [markdown]
# # Content-Based Filtering
#
# This notebook implements content-based filtering using:
# - TF-IDF vectorization on movie genres
# - Cosine similarity for finding similar movies

# %%
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from data_loader import load_all_data
from preprocessing import preprocess_movies, preprocess_ratings
from content_based import ContentBasedRecommender
from evaluation import evaluate_recommendations, calculate_coverage, calculate_diversity

sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)
